# %% [markdown]
# <a href="https://colab.research.google.com/github/Tamara0409/python/blob/main/2023_08_23_utilidades.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# problema de utilidades
# =============
#
# **Date:** 2023-08-23

# %%
from itertools import combinations

def subconjuntos(conjunto):
    todos = []
    for i in range(len(conjunto)+1):
        for sub in combinations(conjunto, i):
            todos.append(set(sub))

    return todos

subconjuntos({1,5,8})
# Out:
# [set(), {8}, {1}, {5}, {1, 8}, {5, 8}, {1, 5}, {1, 5, 8}]

# %% [markdown]
# utilidad -> *profit*
#
# peso -> *weight*

# %%
utilidad = {"linterna":10, "libro":2, "baterías":4, "lata":7, "bolsa de dormir": 20, "mapa":6, "celular":7, "encendedor": 8, "asador":6, "computadora":4,"cuchillo":10 }

peso = {"linterna":3, "libro":5, "baterías":1, "lata":3, "bolsa de dormir": 8, "mapa":1, "celular": 2, "encendedor":1, "asador":10, "computadora":8,"cuchillo":4 }

# %%
for objeto in utilidad.keys():
    print(f"El objeto '{objeto}' tiene utilidad {utilidad[objeto]}.")
# Out:
# El objeto 'linterna' tiene utilidad 10.
# El objeto 'libro' tiene utilidad 2.
# El objeto 'baterías' tiene utilidad 4.
# El objeto 'lata' tiene utilidad 7.
# El objeto 'bolsa de dormir' tiene utilidad 20.
# El objeto 'mapa' tiene utilidad 6.
# El objeto 'celular' tiene utilidad 7.
# El objeto 'encendedor' tiene utilidad 8.
# El objeto 'asador' tiene utilidad 6.
# El objeto 'computadora' tiene utilidad 4.
# El objeto 'cuchillo' tiene utilidad 10.

# %% [markdown]
# En realidad, no se necesita decir explícitamente que se van a recorrer las llaves para recorrer un diccionario:

# %%
for objeto in utilidad:
    print(f"El objeto '{objeto}' tiene utilidad {utilidad[objeto]}.")
# Out:
# El objeto 'linterna' tiene utilidad 10.
# El objeto 'libro' tiene utilidad 2.
# El objeto 'baterías' tiene utilidad 4.
# El objeto 'lata' tiene utilidad 7.
# El objeto 'bolsa de dormir' tiene utilidad 20.
# El objeto 'mapa' tiene utilidad 6.
# El objeto 'celular' tiene utilidad 7.
# El objeto 'encendedor' tiene utilidad 8.
# El objeto 'asador' tiene utilidad 6.
# El objeto 'computadora' tiene utilidad 4.
# El objeto 'cuchillo' tiene utilidad 10.

# %% [markdown]
# Ejercicio: Definir una función que, dado un subconjunto de los objetos, determine la suma de los pesos o de las utilidades. Es decir, `tarea({"mapa", "celular"}, utilidad)` debe regresar 13.
#
# Sugerencia: Usar la función `sum`.

# %%
sum([4,5,10])
# Out:
# 19

# %%
def suma(conjunto, parámetro):
    valores = [parámetro[objeto] for objeto in conjunto]
    return sum(valores)

suma(conjunto={"linterna", "lata"}, parámetro=peso)
# Out:
# 6

# %%
def todos_subconjuntos(conjunto):
    return [set(subconjunto) for i in range(len(conjunto)+1) for subconjunto \
            in combinations(conjunto, i)]

todos_subconjuntos({1,-6,6})
# Out:
# [set(), {1}, {-6}, {6}, {-6, 1}, {1, 6}, {-6, 6}, {-6, 1, 6}]

# %%
for conjunto in todos_subconjuntos(utilidad):
    print(f"El conjunto {conjunto} tiene utilidad {suma(conjunto, utilidad)}.")
# Out:
# El conjunto set() tiene utilidad 0.
# El conjunto {'linterna'} tiene utilidad 10.
# El conjunto {'libro'} tiene utilidad 2.
# El conjunto {'baterías'} tiene utilidad 4.
# El conjunto {'lata'} tiene utilidad 7.
# El conjunto {'bolsa de dormir'} tiene utilidad 20.
# El conjunto {'mapa'} tiene utilidad 6.
# El conjunto {'celular'} tiene utilidad 7.
# El conjunto {'encendedor'} tiene utilidad 8.
# El conjunto {'asador'} tiene utilidad 6.
# El conjunto {'computadora'} tiene utilidad 4.
# El conjunto {'cuchillo'} tiene utilidad 10.
# El conjunto {'libro', 'linterna'} tiene utilidad 12.
# El conjunto {'baterías', 'linterna'} tiene utilidad 14.
# El conjunto {'lata', 'linterna'} tiene utilidad 17.
# El conjunto {'bolsa de dormir', 'linterna'} tiene utilidad 30.
# El conjunto {'mapa', 'linterna'} tiene utilidad 16.
# El conjunto {'celular', 'linterna'} tiene utilidad 17.
# El conjunto {'encendedor', 'linterna'} tiene utilidad 18.
# El conjunto {'asador', 'linterna'} tiene utilidad 16.
# El conjunto {'computadora', 'linterna'} tiene utilidad 14.
# El conjunto {'cuchillo', 'linterna'} tiene utilidad 20.
# El conjunto {'baterías', 'libro'} tiene utilidad 6.
# El conjunto {'libro', 'lata'} tiene utilidad 9.
# El conjunto {'bolsa de dormir', 'libro'} tiene utilidad 22.
# El conjunto {'mapa', 'libro'} tiene utilidad 8.
# El conjunto {'libro', 'celular'} tiene utilidad 9.
# El conjunto {'libro', 'encendedor'} tiene utilidad 10.
# El conjunto {'libro', 'asador'} tiene utilidad 8.
# El conjunto {'libro', 'computadora'} tiene utilidad 6.
# El conjunto {'cuchillo', 'libro'} tiene utilidad 12.
# El conjunto {'baterías', 'lata'} tiene utilidad 11.
# El conjunto {'bolsa de dormir', 'baterías'} tiene utilidad 24.
# El conjunto {'mapa', 'baterías'} tiene utilidad 10.
# El conjunto {'baterías', 'celular'} tiene utilidad 11.
# El conjunto {'baterías', 'encendedor'} tiene utilidad 12.
# El conjunto {'baterías', 'asador'} tiene utilidad 10.
# El conjunto {'baterías', 'computadora'} tiene utilidad 8.
# El conjunto {'baterías', 'cuchillo'} tiene utilidad 14.
# El conjunto {'bolsa de dormir', 'lata'} tiene utilidad 27.
# El conjunto {'mapa', 'lata'} tiene utilidad 13.
# El conjunto {'celular', 'lata'} tiene utilidad 14.
# El conjunto {'encendedor', 'lata'} tiene utilidad 15.
# El conjunto {'asador', 'lata'} tiene utilidad 13.
# El conjunto {'computadora', 'lata'} tiene utilidad 11.
# El conjunto {'cuchillo', 'lata'} tiene utilidad 17.
# El conjunto {'bolsa de dormir', 'mapa'} tiene utilidad 26.
# El conjunto {'bolsa de dormir', 'celular'} tiene utilidad 27.
# El conjunto {'bolsa de dormir', 'encendedor'} tiene utilidad 28.
# El conjunto {'bolsa de dormir', 'asador'} tiene utilidad 26.
# El conjunto {'bolsa de dormir', 'computadora'} tiene utilidad 24.
# El conjunto {'bolsa de dormir', 'cuchillo'} tiene utilidad 30.
# El conjunto {'mapa', 'celular'} tiene utilidad 13.
# El conjunto {'mapa', 'encendedor'} tiene utilidad 14.
# El conjunto {'mapa', 'asador'} tiene utilidad 12.
# El conjunto {'mapa', 'computadora'} tiene utilidad 10.
# El conjunto {'mapa', 'cuchillo'} tiene utilidad 16.
# El conjunto {'encendedor', 'celular'} tiene utilidad 15.
# El conjunto {'asador', 'celular'} tiene utilidad 13.
# El conjunto {'computadora', 'celular'} tiene utilidad 11.
# El conjunto {'cuchillo', 'celular'} tiene utilidad 17.
# El conjunto {'asador', 'encendedor'} tiene utilidad 14.
# El conjunto {'computadora', 'encendedor'} tiene utilidad 12.
# El conjunto {'cuchillo', 'encendedor'} tiene utilidad 18.
# El conjunto {'asador', 'computadora'} tiene utilidad 10.
# El conjunto {'cuchillo', 'asador'} tiene utilidad 16.
# El conjunto {'cuchillo', 'computadora'} tiene utilidad 14.
# El conjunto {'baterías', 'libro', 'linterna'} tiene utilidad 16.
# El conjunto {'lata', 'libro', 'linterna'} tiene utilidad 19.
# El conjunto {'bolsa de dormir', 'libro', 'linterna'} tiene utilidad 32.
# El conjunto {'mapa', 'libro', 'linterna'} tiene utilidad 18.
# El conjunto {'celular', 'libro', 'linterna'} tiene utilidad 19.
# El conjunto {'encendedor', 'libro', 'linterna'} tiene utilidad 20.
# El conjunto {'libro', 'asador', 'linterna'} tiene utilidad 18.
# El conjunto {'libro', 'computadora', 'linterna'} tiene utilidad 16.
# El conjunto {'cuchillo', 'libro', 'linterna'} tiene utilidad 22.
# El conjunto {'baterías', 'lata', 'linterna'} tiene utilidad 21.
# El conjunto {'bolsa de dormir', 'baterías', 'linterna'} tiene utilidad 34.
# El conjunto {'mapa', 'baterías', 'linterna'} tiene utilidad 20.
# El conjunto {'celular', 'baterías', 'linterna'} tiene utilidad 21.
# El conjunto {'encendedor', 'baterías', 'linterna'} tiene utilidad 22.
# El conjunto {'baterías', 'asador', 'linterna'} tiene utilidad 20.
# El conjunto {'baterías', 'computadora', 'linterna'} tiene utilidad 18.
# El conjunto {'baterías', 'cuchillo', 'linterna'} tiene utilidad 24.
# El conjunto {'bolsa de dormir', 'lata', 'linterna'} tiene utilidad 37.
# El conjunto {'mapa', 'lata', 'linterna'} tiene utilidad 23.
# El conjunto {'celular', 'lata', 'linterna'} tiene utilidad 24.
# El conjunto {'encendedor', 'lata', 'linterna'} tiene utilidad 25.
# El conjunto {'lata', 'asador', 'linterna'} tiene utilidad 23.
# El conjunto {'lata', 'computadora', 'linterna'} tiene utilidad 21.
# El conjunto {'lata', 'cuchillo', 'linterna'} tiene utilidad 27.
# El conjunto {'bolsa de dormir', 'mapa', 'linterna'} tiene utilidad 36.
# El conjunto {'celular', 'bolsa de dormir', 'linterna'} tiene utilidad 37.
# El conjunto {'bolsa de dormir', 'encendedor', 'linterna'} tiene utilidad 38.
# El conjunto {'bolsa de dormir', 'asador', 'linterna'} tiene utilidad 36.
# El conjunto {'bolsa de dormir', 'computadora', 'linterna'} tiene utilidad 34.
# El conjunto {'bolsa de dormir', 'cuchillo', 'linterna'} tiene utilidad 40.
# El conjunto {'celular', 'mapa', 'linterna'} tiene utilidad 23.
# El conjunto {'mapa', 'encendedor', 'linterna'} tiene utilidad 24.
# El conjunto {'mapa', 'asador', 'linterna'} tiene utilidad 22.
# El conjunto {'mapa', 'computadora', 'linterna'} tiene utilidad 20.
# El conjunto {'mapa', 'cuchillo', 'linterna'} tiene utilidad 26.
# El conjunto {'celular', 'encendedor', 'linterna'} tiene utilidad 25.
# El conjunto {'celular', 'asador', 'linterna'} tiene utilidad 23.
# El conjunto {'celular', 'computadora', 'linterna'} tiene utilidad 21.
# El conjunto {'celular', 'cuchillo', 'linterna'} tiene utilidad 27.
# El conjunto {'encendedor', 'asador', 'linterna'} tiene utilidad 24.
# El conjunto {'encendedor', 'computadora', 'linterna'} tiene utilidad 22.
# El conjunto {'encendedor', 'cuchillo', 'linterna'} tiene utilidad 28.
# El conjunto {'asador', 'computadora', 'linterna'} tiene utilidad 20.
# El conjunto {'cuchillo', 'asador', 'linterna'} tiene utilidad 26.
# El conjunto {'cuchillo', 'computadora', 'linterna'} tiene utilidad 24.
# El conjunto {'baterías', 'libro', 'lata'} tiene utilidad 13.
# El conjunto {'bolsa de dormir', 'baterías', 'libro'} tiene utilidad 26.
# El conjunto {'mapa', 'baterías', 'libro'} tiene utilidad 12.
# El conjunto {'baterías', 'libro', 'celular'} tiene utilidad 13.
# El conjunto {'baterías', 'libro', 'encendedor'} tiene utilidad 14.
# El conjunto {'baterías', 'libro', 'asador'} tiene utilidad 12.
# El conjunto {'baterías', 'libro', 'computadora'} tiene utilidad 10.
# El conjunto {'baterías', 'libro', 'cuchillo'} tiene utilidad 16.
# El conjunto {'bolsa de dormir', 'libro', 'lata'} tiene utilidad 29.
# El conjunto {'mapa', 'libro', 'lata'} tiene utilidad 15.
# El conjunto {'celular', 'libro', 'lata'} tiene utilidad 16.
# El conjunto {'encendedor', 'libro', 'lata'} tiene utilidad 17.
# El conjunto {'libro', 'asador', 'lata'} tiene utilidad 15.
# El conjunto {'libro', 'computadora', 'lata'} tiene utilidad 13.
# El conjunto {'cuchillo', 'libro', 'lata'} tiene utilidad 19.
# El conjunto {'bolsa de dormir', 'libro', 'mapa'} tiene utilidad 28.
# El conjunto {'bolsa de dormir', 'libro', 'celular'} tiene utilidad 29.
# El conjunto {'bolsa de dormir', 'libro', 'encendedor'} tiene utilidad 30.
# El conjunto {'bolsa de dormir', 'libro', 'asador'} tiene utilidad 28.
# El conjunto {'bolsa de dormir', 'libro', 'computadora'} tiene utilidad 26.
# El conjunto {'bolsa de dormir', 'cuchillo', 'libro'} tiene utilidad 32.
# El conjunto {'mapa', 'libro', 'celular'} tiene utilidad 15.
# El conjunto {'mapa', 'libro', 'encendedor'} tiene utilidad 16.
# El conjunto {'mapa', 'libro', 'asador'} tiene utilidad 14.
# El conjunto {'mapa', 'libro', 'computadora'} tiene utilidad 12.
# El conjunto {'mapa', 'cuchillo', 'libro'} tiene utilidad 18.
# El conjunto {'encendedor', 'libro', 'celular'} tiene utilidad 17.
# El conjunto {'libro', 'asador', 'celular'} tiene utilidad 15.
# El conjunto {'libro', 'computadora', 'celular'} tiene utilidad 13.
# El conjunto {'cuchillo', 'libro', 'celular'} tiene utilidad 19.
# El conjunto {'libro', 'asador', 'encendedor'} tiene utilidad 16.
# El conjunto {'libro', 'computadora', 'encendedor'} tiene utilidad 14.
# El conjunto {'cuchillo', 'libro', 'encendedor'} tiene utilidad 20.
# El conjunto {'computadora', 'libro', 'asador'} tiene utilidad 12.
# El conjunto {'cuchillo', 'libro', 'asador'} tiene utilidad 18.
# El conjunto {'cuchillo', 'libro', 'computadora'} tiene utilidad 16.
# El conjunto {'bolsa de dormir', 'baterías', 'lata'} tiene utilidad 31.
# El conjunto {'mapa', 'baterías', 'lata'} tiene utilidad 17.
# El conjunto {'celular', 'baterías', 'lata'} tiene utilidad 18.
# El conjunto {'encendedor', 'baterías', 'lata'} tiene utilidad 19.
# El conjunto {'baterías', 'asador', 'lata'} tiene utilidad 17.
# El conjunto {'baterías', 'computadora', 'lata'} tiene utilidad 15.
# El conjunto {'baterías', 'cuchillo', 'lata'} tiene utilidad 21.
# El conjunto {'bolsa de dormir', 'baterías', 'mapa'} tiene utilidad 30.
# El conjunto {'bolsa de dormir', 'baterías', 'celular'} tiene utilidad 31.
# El conjunto {'bolsa de dormir', 'baterías', 'encendedor'} tiene utilidad 32.
# El conjunto {'bolsa de dormir', 'baterías', 'asador'} tiene utilidad 30.
# El conjunto {'bolsa de dormir', 'baterías', 'computadora'} tiene utilidad 28.
# El conjunto {'bolsa de dormir', 'baterías', 'cuchillo'} tiene utilidad 34.
# El conjunto {'mapa', 'baterías', 'celular'} tiene utilidad 17.
# El conjunto {'mapa', 'baterías', 'encendedor'} tiene utilidad 18.
# El conjunto {'mapa', 'baterías', 'asador'} tiene utilidad 16.
# El conjunto {'mapa', 'baterías', 'computadora'} tiene utilidad 14.
# El conjunto {'mapa', 'baterías', 'cuchillo'} tiene utilidad 20.
# El conjunto {'encendedor', 'baterías', 'celular'} tiene utilidad 19.
# El conjunto {'baterías', 'asador', 'celular'} tiene utilidad 17.
# El conjunto {'baterías', 'computadora', 'celular'} tiene utilidad 15.
# El conjunto {'baterías', 'cuchillo', 'celular'} tiene utilidad 21.
# El conjunto {'baterías', 'asador', 'encendedor'} tiene utilidad 18.
# El conjunto {'baterías', 'computadora', 'encendedor'} tiene utilidad 16.
# El conjunto {'baterías', 'cuchillo', 'encendedor'} tiene utilidad 22.
# El conjunto {'baterías', 'asador', 'computadora'} tiene utilidad 14.
# El conjunto {'baterías', 'asador', 'cuchillo'} tiene utilidad 20.
# El conjunto {'baterías', 'cuchillo', 'computadora'} tiene utilidad 18.
# El conjunto {'bolsa de dormir', 'mapa', 'lata'} tiene utilidad 33.
# El conjunto {'celular', 'bolsa de dormir', 'lata'} tiene utilidad 34.
# El conjunto {'bolsa de dormir', 'encendedor', 'lata'} tiene utilidad 35.
# El conjunto {'bolsa de dormir', 'asador', 'lata'} tiene utilidad 33.
# El conjunto {'bolsa de dormir', 'computadora', 'lata'} tiene utilidad 31.
# El conjunto {'bolsa de dormir', 'cuchillo', 'lata'} tiene utilidad 37.
# El conjunto {'celular', 'mapa', 'lata'} tiene utilidad 20.
# El conjunto {'mapa', 'encendedor', 'lata'} tiene utilidad 21.
# El conjunto {'mapa', 'asador', 'lata'} tiene utilidad 19.
# El conjunto {'mapa', 'computadora', 'lata'} tiene utilidad 17.
# El conjunto {'mapa', 'cuchillo', 'lata'} tiene utilidad 23.
# El conjunto {'celular', 'encendedor', 'lata'} tiene utilidad 22.
# El conjunto {'celular', 'asador', 'lata'} tiene utilidad 20.
# El conjunto {'celular', 'computadora', 'lata'} tiene utilidad 18.
# El conjunto {'celular', 'cuchillo', 'lata'} tiene utilidad 24.
# El conjunto {'encendedor', 'asador', 'lata'} tiene utilidad 21.
# El conjunto {'encendedor', 'computadora', 'lata'} tiene utilidad 19.
# El conjunto {'encendedor', 'cuchillo', 'lata'} tiene utilidad 25.
# El conjunto {'asador', 'computadora', 'lata'} tiene utilidad 17.
# El conjunto {'cuchillo', 'asador', 'lata'} tiene utilidad 23.
# El conjunto {'cuchillo', 'computadora', 'lata'} tiene utilidad 21.
# El conjunto {'bolsa de dormir', 'mapa', 'celular'} tiene utilidad 33.
# El conjunto {'bolsa de dormir', 'mapa', 'encendedor'} tiene utilidad 34.
# El conjunto {'bolsa de dormir', 'asador', 'mapa'} tiene utilidad 32.
# El conjunto {'computadora', 'bolsa de dormir', 'mapa'} tiene utilidad 30.
# El conjunto {'bolsa de dormir', 'cuchillo', 'mapa'} tiene utilidad 36.
# El conjunto {'bolsa de dormir', 'encendedor', 'celular'} tiene utilidad 35.
# El conjunto {'bolsa de dormir', 'asador', 'celular'} tiene utilidad 33.
# El conjunto {'bolsa de dormir', 'computadora', 'celular'} tiene utilidad 31.
# El conjunto {'bolsa de dormir', 'cuchillo', 'celular'} tiene utilidad 37.
# El conjunto {'bolsa de dormir', 'asador', 'encendedor'} tiene utilidad 34.
# El conjunto {'bolsa de dormir', 'computadora', 'encendedor'} tiene utilidad 32.
# El conjunto {'bolsa de dormir', 'cuchillo', 'encendedor'} tiene utilidad 38.
# El conjunto {'bolsa de dormir', 'asador', 'computadora'} tiene utilidad 30.
# El conjunto {'bolsa de dormir', 'cuchillo', 'asador'} tiene utilidad 36.
# El conjunto {'bolsa de dormir', 'cuchillo', 'computadora'} tiene utilidad 34.
# El conjunto {'mapa', 'encendedor', 'celular'} tiene utilidad 21.
# El conjunto {'mapa', 'asador', 'celular'} tiene utilidad 19.
# El conjunto {'mapa', 'computadora', 'celular'} tiene utilidad 17.
# El conjunto {'mapa', 'cuchillo', 'celular'} tiene utilidad 23.
# El conjunto {'mapa', 'asador', 'encendedor'} tiene utilidad 20.
# El conjunto {'mapa', 'computadora', 'encendedor'} tiene utilidad 18.
# El conjunto {'mapa', 'cuchillo', 'encendedor'} tiene utilidad 24.
# El conjunto {'mapa', 'asador', 'computadora'} tiene utilidad 16.
# El conjunto {'mapa', 'cuchillo', 'asador'} tiene utilidad 22.
# El conjunto {'mapa', 'cuchillo', 'computadora'} tiene utilidad 20.
# El conjunto {'encendedor', 'asador', 'celular'} tiene utilidad 21.
# El conjunto {'encendedor', 'computadora', 'celular'} tiene utilidad 19.
# El conjunto {'encendedor', 'cuchillo', 'celular'} tiene utilidad 25.
# El conjunto {'asador', 'computadora', 'celular'} tiene utilidad 17.
# El conjunto {'cuchillo', 'asador', 'celular'} tiene utilidad 23.
# El conjunto {'cuchillo', 'computadora', 'celular'} tiene utilidad 21.
# El conjunto {'asador', 'computadora', 'encendedor'} tiene utilidad 18.
# El conjunto {'cuchillo', 'asador', 'encendedor'} tiene utilidad 24.
# El conjunto {'cuchillo', 'computadora', 'encendedor'} tiene utilidad 22.
# El conjunto {'cuchillo', 'asador', 'computadora'} tiene utilidad 20.
# El conjunto {'baterías', 'libro', 'lata', 'linterna'} tiene utilidad 23.
# El conjunto {'bolsa de dormir', 'baterías', 'libro', 'linterna'} tiene utilidad 36.
# El conjunto {'mapa', 'baterías', 'libro', 'linterna'} tiene utilidad 22.
# El conjunto {'celular', 'baterías', 'libro', 'linterna'} tiene utilidad 23.
# El conjunto {'encendedor', 'baterías', 'libro', 'linterna'} tiene utilidad 24.
# El conjunto {'baterías', 'libro', 'asador', 'linterna'} tiene utilidad 22.
# El conjunto {'baterías', 'libro', 'computadora', 'linterna'} tiene utilidad 20.
# El conjunto {'baterías', 'libro', 'cuchillo', 'linterna'} tiene utilidad 26.
# El conjunto {'bolsa de dormir', 'lata', 'libro', 'linterna'} tiene utilidad 39.
# El conjunto {'mapa', 'lata', 'libro', 'linterna'} tiene utilidad 25.
# El conjunto {'celular', 'lata', 'libro', 'linterna'} tiene utilidad 26.
# El conjunto {'encendedor', 'lata', 'libro', 'linterna'} tiene utilidad 27.
# El conjunto {'lata', 'libro', 'asador', 'linterna'} tiene utilidad 25.
# El conjunto {'lata', 'libro', 'computadora', 'linterna'} tiene utilidad 23.
# El conjunto {'lata', 'libro', 'cuchillo', 'linterna'} tiene utilidad 29.
# El conjunto {'bolsa de dormir', 'libro', 'mapa', 'linterna'} tiene utilidad 38.
# El conjunto {'celular', 'bolsa de dormir', 'libro', 'linterna'} tiene utilidad 39.
# El conjunto {'bolsa de dormir', 'libro', 'encendedor', 'linterna'} tiene utilidad 40.
# El conjunto {'bolsa de dormir', 'libro', 'asador', 'linterna'} tiene utilidad 38.
# El conjunto {'bolsa de dormir', 'libro', 'computadora', 'linterna'} tiene utilidad 36.
# El conjunto {'bolsa de dormir', 'cuchillo', 'libro', 'linterna'} tiene utilidad 42.
# El conjunto {'celular', 'mapa', 'libro', 'linterna'} tiene utilidad 25.
# El conjunto {'mapa', 'libro', 'encendedor', 'linterna'} tiene utilidad 26.
# El conjunto {'mapa', 'libro', 'asador', 'linterna'} tiene utilidad 24.
# El conjunto {'mapa', 'libro', 'computadora', 'linterna'} tiene utilidad 22.
# El conjunto {'mapa', 'cuchillo', 'libro', 'linterna'} tiene utilidad 28.
# El conjunto {'celular', 'encendedor', 'libro', 'linterna'} tiene utilidad 27.
# El conjunto {'celular', 'libro', 'asador', 'linterna'} tiene utilidad 25.
# El conjunto {'celular', 'libro', 'computadora', 'linterna'} tiene utilidad 23.
# El conjunto {'celular', 'cuchillo', 'libro', 'linterna'} tiene utilidad 29.
# El conjunto {'encendedor', 'libro', 'asador', 'linterna'} tiene utilidad 26.
# El conjunto {'encendedor', 'libro', 'computadora', 'linterna'} tiene utilidad 24.
# El conjunto {'encendedor', 'cuchillo', 'libro', 'linterna'} tiene utilidad 30.
# El conjunto {'computadora', 'libro', 'asador', 'linterna'} tiene utilidad 22.
# El conjunto {'cuchillo', 'libro', 'asador', 'linterna'} tiene utilidad 28.
# El conjunto {'cuchillo', 'libro', 'computadora', 'linterna'} tiene utilidad 26.
# El conjunto {'bolsa de dormir', 'baterías', 'lata', 'linterna'} tiene utilidad 41.
# El conjunto {'mapa', 'baterías', 'lata', 'linterna'} tiene utilidad 27.
# El conjunto {'celular', 'baterías', 'lata', 'linterna'} tiene utilidad 28.
# El conjunto {'encendedor', 'baterías', 'lata', 'linterna'} tiene utilidad 29.
# El conjunto {'baterías', 'asador', 'lata', 'linterna'} tiene utilidad 27.
# El conjunto {'computadora', 'baterías', 'lata', 'linterna'} tiene utilidad 25.
# El conjunto {'baterías', 'cuchillo', 'lata', 'linterna'} tiene utilidad 31.
# El conjunto {'bolsa de dormir', 'baterías', 'mapa', 'linterna'} tiene utilidad 40.
# El conjunto {'celular', 'bolsa de dormir', 'baterías', 'linterna'} tiene utilidad 41.
# El conjunto {'bolsa de dormir', 'baterías', 'encendedor', 'linterna'} tiene utilidad 42.
# El conjunto {'bolsa de dormir', 'baterías', 'asador', 'linterna'} tiene utilidad 40.
# El conjunto {'bolsa de dormir', 'baterías', 'computadora', 'linterna'} tiene utilidad 38.
# El conjunto {'bolsa de dormir', 'baterías', 'cuchillo', 'linterna'} tiene utilidad 44.
# El conjunto {'celular', 'mapa', 'baterías', 'linterna'} tiene utilidad 27.
# El conjunto {'mapa', 'baterías', 'encendedor', 'linterna'} tiene utilidad 28.
# El conjunto {'mapa', 'baterías', 'asador', 'linterna'} tiene utilidad 26.
# El conjunto {'mapa', 'baterías', 'computadora', 'linterna'} tiene utilidad 24.
# El conjunto {'mapa', 'baterías', 'cuchillo', 'linterna'} tiene utilidad 30.
# El conjunto {'celular', 'encendedor', 'baterías', 'linterna'} tiene utilidad 29.
# El conjunto {'celular', 'baterías', 'asador', 'linterna'} tiene utilidad 27.
# El conjunto {'celular', 'baterías', 'computadora', 'linterna'} tiene utilidad 25.
# El conjunto {'celular', 'baterías', 'cuchillo', 'linterna'} tiene utilidad 31.
# El conjunto {'encendedor', 'baterías', 'asador', 'linterna'} tiene utilidad 28.
# El conjunto {'encendedor', 'baterías', 'computadora', 'linterna'} tiene utilidad 26.
# El conjunto {'encendedor', 'baterías', 'cuchillo', 'linterna'} tiene utilidad 32.
# El conjunto {'baterías', 'asador', 'computadora', 'linterna'} tiene utilidad 24.
# El conjunto {'baterías', 'asador', 'cuchillo', 'linterna'} tiene utilidad 30.
# El conjunto {'baterías', 'cuchillo', 'computadora', 'linterna'} tiene utilidad 28.
# El conjunto {'bolsa de dormir', 'lata', 'mapa', 'linterna'} tiene utilidad 43.
# El conjunto {'celular', 'bolsa de dormir', 'lata', 'linterna'} tiene utilidad 44.
# El conjunto {'bolsa de dormir', 'lata', 'encendedor', 'linterna'} tiene utilidad 45.
# El conjunto {'bolsa de dormir', 'lata', 'asador', 'linterna'} tiene utilidad 43.
# El conjunto {'bolsa de dormir', 'lata', 'computadora', 'linterna'} tiene utilidad 41.
# El conjunto {'bolsa de dormir', 'lata', 'cuchillo', 'linterna'} tiene utilidad 47.
# El conjunto {'celular', 'mapa', 'lata', 'linterna'} tiene utilidad 30.
# El conjunto {'mapa', 'lata', 'encendedor', 'linterna'} tiene utilidad 31.
# El conjunto {'mapa', 'lata', 'asador', 'linterna'} tiene utilidad 29.
# El conjunto {'mapa', 'lata', 'computadora', 'linterna'} tiene utilidad 27.
# El conjunto {'mapa', 'lata', 'cuchillo', 'linterna'} tiene utilidad 33.
# El conjunto {'celular', 'encendedor', 'lata', 'linterna'} tiene utilidad 32.
# El conjunto {'celular', 'lata', 'asador', 'linterna'} tiene utilidad 30.
# El conjunto {'celular', 'lata', 'computadora', 'linterna'} tiene utilidad 28.
# El conjunto {'celular', 'lata', 'cuchillo', 'linterna'} tiene utilidad 34.
# El conjunto {'encendedor', 'lata', 'asador', 'linterna'} tiene utilidad 31.
# El conjunto {'encendedor', 'lata', 'computadora', 'linterna'} tiene utilidad 29.
# El conjunto {'encendedor', 'lata', 'cuchillo', 'linterna'} tiene utilidad 35.
# El conjunto {'lata', 'asador', 'computadora', 'linterna'} tiene utilidad 27.
# El conjunto {'lata', 'asador', 'cuchillo', 'linterna'} tiene utilidad 33.
# El conjunto {'lata', 'cuchillo', 'computadora', 'linterna'} tiene utilidad 31.
# El conjunto {'celular', 'bolsa de dormir', 'mapa', 'linterna'} tiene utilidad 43.
# El conjunto {'bolsa de dormir', 'encendedor', 'mapa', 'linterna'} tiene utilidad 44.
# El conjunto {'bolsa de dormir', 'asador', 'mapa', 'linterna'} tiene utilidad 42.
# El conjunto {'computadora', 'bolsa de dormir', 'mapa', 'linterna'} tiene utilidad 40.
# El conjunto {'bolsa de dormir', 'cuchillo', 'mapa', 'linterna'} tiene utilidad 46.
# El conjunto {'celular', 'bolsa de dormir', 'encendedor', 'linterna'} tiene utilidad 45.
# El conjunto {'celular', 'bolsa de dormir', 'asador', 'linterna'} tiene utilidad 43.
# El conjunto {'celular', 'bolsa de dormir', 'computadora', 'linterna'} tiene utilidad 41.
# El conjunto {'celular', 'bolsa de dormir', 'cuchillo', 'linterna'} tiene utilidad 47.
# El conjunto {'bolsa de dormir', 'asador', 'encendedor', 'linterna'} tiene utilidad 44.
# El conjunto {'bolsa de dormir', 'encendedor', 'computadora', 'linterna'} tiene utilidad 42.
# El conjunto {'bolsa de dormir', 'cuchillo', 'encendedor', 'linterna'} tiene utilidad 48.
# El conjunto {'bolsa de dormir', 'asador', 'computadora', 'linterna'} tiene utilidad 40.
# El conjunto {'bolsa de dormir', 'cuchillo', 'asador', 'linterna'} tiene utilidad 46.
# El conjunto {'bolsa de dormir', 'cuchillo', 'computadora', 'linterna'} tiene utilidad 44.
# El conjunto {'celular', 'mapa', 'encendedor', 'linterna'} tiene utilidad 31.
# El conjunto {'celular', 'mapa', 'asador', 'linterna'} tiene utilidad 29.
# El conjunto {'celular', 'mapa', 'computadora', 'linterna'} tiene utilidad 27.
# El conjunto {'celular', 'mapa', 'cuchillo', 'linterna'} tiene utilidad 33.
# El conjunto {'mapa', 'asador', 'encendedor', 'linterna'} tiene utilidad 30.
# El conjunto {'mapa', 'encendedor', 'computadora', 'linterna'} tiene utilidad 28.
# El conjunto {'mapa', 'cuchillo', 'encendedor', 'linterna'} tiene utilidad 34.
# El conjunto {'mapa', 'asador', 'computadora', 'linterna'} tiene utilidad 26.
# El conjunto {'mapa', 'cuchillo', 'asador', 'linterna'} tiene utilidad 32.
# El conjunto {'mapa', 'cuchillo', 'computadora', 'linterna'} tiene utilidad 30.
# El conjunto {'celular', 'encendedor', 'asador', 'linterna'} tiene utilidad 31.
# El conjunto {'celular', 'encendedor', 'computadora', 'linterna'} tiene utilidad 29.
# El conjunto {'celular', 'encendedor', 'cuchillo', 'linterna'} tiene utilidad 35.
# El conjunto {'celular', 'asador', 'computadora', 'linterna'} tiene utilidad 27.
# El conjunto {'celular', 'cuchillo', 'asador', 'linterna'} tiene utilidad 33.
# El conjunto {'celular', 'cuchillo', 'computadora', 'linterna'} tiene utilidad 31.
# El conjunto {'encendedor', 'asador', 'computadora', 'linterna'} tiene utilidad 28.
# El conjunto {'encendedor', 'cuchillo', 'asador', 'linterna'} tiene utilidad 34.
# El conjunto {'encendedor', 'cuchillo', 'computadora', 'linterna'} tiene utilidad 32.
# El conjunto {'cuchillo', 'asador', 'computadora', 'linterna'} tiene utilidad 30.
# El conjunto {'bolsa de dormir', 'baterías', 'libro', 'lata'} tiene utilidad 33.
# El conjunto {'mapa', 'baterías', 'libro', 'lata'} tiene utilidad 19.
# El conjunto {'celular', 'baterías', 'libro', 'lata'} tiene utilidad 20.
# El conjunto {'encendedor', 'baterías', 'libro', 'lata'} tiene utilidad 21.
# El conjunto {'baterías', 'libro', 'asador', 'lata'} tiene utilidad 19.
# El conjunto {'baterías', 'libro', 'computadora', 'lata'} tiene utilidad 17.
# El conjunto {'baterías', 'libro', 'cuchillo', 'lata'} tiene utilidad 23.
# El conjunto {'bolsa de dormir', 'baterías', 'libro', 'mapa'} tiene utilidad 32.
# El conjunto {'bolsa de dormir', 'baterías', 'libro', 'celular'} tiene utilidad 33.
# El conjunto {'bolsa de dormir', 'baterías', 'libro', 'encendedor'} tiene utilidad 34.
# El conjunto {'bolsa de dormir', 'baterías', 'libro', 'asador'} tiene utilidad 32.
# El conjunto {'bolsa de dormir', 'baterías', 'libro', 'computadora'} tiene utilidad 30.
# El conjunto {'bolsa de dormir', 'baterías', 'libro', 'cuchillo'} tiene utilidad 36.
# El conjunto {'mapa', 'baterías', 'libro', 'celular'} tiene utilidad 19.
# El conjunto {'mapa', 'baterías', 'libro', 'encendedor'} tiene utilidad 20.
# El conjunto {'mapa', 'baterías', 'libro', 'asador'} tiene utilidad 18.
# El conjunto {'mapa', 'baterías', 'libro', 'computadora'} tiene utilidad 16.
# El conjunto {'mapa', 'baterías', 'libro', 'cuchillo'} tiene utilidad 22.
# El conjunto {'encendedor', 'baterías', 'libro', 'celular'} tiene utilidad 21.
# El conjunto {'baterías', 'libro', 'asador', 'celular'} tiene utilidad 19.
# El conjunto {'baterías', 'libro', 'computadora', 'celular'} tiene utilidad 17.
# El conjunto {'baterías', 'libro', 'cuchillo', 'celular'} tiene utilidad 23.
# El conjunto {'baterías', 'libro', 'asador', 'encendedor'} tiene utilidad 20.
# El conjunto {'baterías', 'libro', 'computadora', 'encendedor'} tiene utilidad 18.
# El conjunto {'baterías', 'libro', 'cuchillo', 'encendedor'} tiene utilidad 24.
# El conjunto {'computadora', 'baterías', 'libro', 'asador'} tiene utilidad 16.
# El conjunto {'baterías', 'libro', 'cuchillo', 'asador'} tiene utilidad 22.
# El conjunto {'baterías', 'libro', 'cuchillo', 'computadora'} tiene utilidad 20.
# El conjunto {'bolsa de dormir', 'libro', 'mapa', 'lata'} tiene utilidad 35.
# El conjunto {'celular', 'bolsa de dormir', 'libro', 'lata'} tiene utilidad 36.
# El conjunto {'bolsa de dormir', 'libro', 'encendedor', 'lata'} tiene utilidad 37.
# El conjunto {'bolsa de dormir', 'libro', 'asador', 'lata'} tiene utilidad 35.
# El conjunto {'bolsa de dormir', 'libro', 'computadora', 'lata'} tiene utilidad 33.
# El conjunto {'bolsa de dormir', 'cuchillo', 'libro', 'lata'} tiene utilidad 39.
# El conjunto {'celular', 'mapa', 'libro', 'lata'} tiene utilidad 22.
# El conjunto {'mapa', 'libro', 'encendedor', 'lata'} tiene utilidad 23.
# El conjunto {'mapa', 'libro', 'asador', 'lata'} tiene utilidad 21.
# El conjunto {'mapa', 'libro', 'computadora', 'lata'} tiene utilidad 19.
# El conjunto {'mapa', 'cuchillo', 'libro', 'lata'} tiene utilidad 25.
# El conjunto {'celular', 'encendedor', 'libro', 'lata'} tiene utilidad 24.
# El conjunto {'celular', 'libro', 'asador', 'lata'} tiene utilidad 22.
# El conjunto {'celular', 'libro', 'computadora', 'lata'} tiene utilidad 20.
# El conjunto {'celular', 'cuchillo', 'libro', 'lata'} tiene utilidad 26.
# El conjunto {'encendedor', 'libro', 'asador', 'lata'} tiene utilidad 23.
# El conjunto {'encendedor', 'libro', 'computadora', 'lata'} tiene utilidad 21.
# El conjunto {'encendedor', 'cuchillo', 'libro', 'lata'} tiene utilidad 27.
# El conjunto {'computadora', 'libro', 'asador', 'lata'} tiene utilidad 19.
# El conjunto {'cuchillo', 'libro', 'asador', 'lata'} tiene utilidad 25.
# El conjunto {'cuchillo', 'libro', 'computadora', 'lata'} tiene utilidad 23.
# El conjunto {'bolsa de dormir', 'libro', 'mapa', 'celular'} tiene utilidad 35.
# El conjunto {'bolsa de dormir', 'libro', 'mapa', 'encendedor'} tiene utilidad 36.
# El conjunto {'bolsa de dormir', 'libro', 'mapa', 'asador'} tiene utilidad 34.
# El conjunto {'computadora', 'bolsa de dormir', 'libro', 'mapa'} tiene utilidad 32.
# El conjunto {'bolsa de dormir', 'cuchillo', 'libro', 'mapa'} tiene utilidad 38.
# El conjunto {'bolsa de dormir', 'libro', 'encendedor', 'celular'} tiene utilidad 37.
# El conjunto {'bolsa de dormir', 'libro', 'asador', 'celular'} tiene utilidad 35.
# El conjunto {'bolsa de dormir', 'libro', 'computadora', 'celular'} tiene utilidad 33.
# El conjunto {'bolsa de dormir', 'cuchillo', 'libro', 'celular'} tiene utilidad 39.
# El conjunto {'bolsa de dormir', 'libro', 'asador', 'encendedor'} tiene utilidad 36.
# El conjunto {'bolsa de dormir', 'libro', 'computadora', 'encendedor'} tiene utilidad 34.
# El conjunto {'bolsa de dormir', 'cuchillo', 'libro', 'encendedor'} tiene utilidad 40.
# El conjunto {'computadora', 'bolsa de dormir', 'libro', 'asador'} tiene utilidad 32.
# El conjunto {'bolsa de dormir', 'cuchillo', 'libro', 'asador'} tiene utilidad 38.
# El conjunto {'bolsa de dormir', 'cuchillo', 'libro', 'computadora'} tiene utilidad 36.
# El conjunto {'mapa', 'libro', 'encendedor', 'celular'} tiene utilidad 23.
# El conjunto {'mapa', 'libro', 'asador', 'celular'} tiene utilidad 21.
# El conjunto {'mapa', 'libro', 'computadora', 'celular'} tiene utilidad 19.
# El conjunto {'mapa', 'cuchillo', 'libro', 'celular'} tiene utilidad 25.
# El conjunto {'mapa', 'libro', 'asador', 'encendedor'} tiene utilidad 22.
# El conjunto {'mapa', 'libro', 'computadora', 'encendedor'} tiene utilidad 20.
# El conjunto {'mapa', 'cuchillo', 'libro', 'encendedor'} tiene utilidad 26.
# El conjunto {'computadora', 'mapa', 'libro', 'asador'} tiene utilidad 18.
# El conjunto {'mapa', 'cuchillo', 'libro', 'asador'} tiene utilidad 24.
# El conjunto {'mapa', 'cuchillo', 'libro', 'computadora'} tiene utilidad 22.
# El conjunto {'encendedor', 'libro', 'asador', 'celular'} tiene utilidad 23.
# El conjunto {'encendedor', 'libro', 'computadora', 'celular'} tiene utilidad 21.
# El conjunto {'encendedor', 'cuchillo', 'libro', 'celular'} tiene utilidad 27.
# El conjunto {'computadora', 'libro', 'asador', 'celular'} tiene utilidad 19.
# El conjunto {'cuchillo', 'libro', 'asador', 'celular'} tiene utilidad 25.
# El conjunto {'cuchillo', 'libro', 'computadora', 'celular'} tiene utilidad 23.
# El conjunto {'computadora', 'libro', 'asador', 'encendedor'} tiene utilidad 20.
# El conjunto {'cuchillo', 'libro', 'asador', 'encendedor'} tiene utilidad 26.
# El conjunto {'cuchillo', 'libro', 'computadora', 'encendedor'} tiene utilidad 24.
# El conjunto {'computadora', 'cuchillo', 'libro', 'asador'} tiene utilidad 22.
# El conjunto {'bolsa de dormir', 'baterías', 'mapa', 'lata'} tiene utilidad 37.
# El conjunto {'celular', 'bolsa de dormir', 'baterías', 'lata'} tiene utilidad 38.
# El conjunto {'bolsa de dormir', 'baterías', 'encendedor', 'lata'} tiene utilidad 39.
# El conjunto {'bolsa de dormir', 'baterías', 'asador', 'lata'} tiene utilidad 37.
# El conjunto {'bolsa de dormir', 'baterías', 'computadora', 'lata'} tiene utilidad 35.
# El conjunto {'bolsa de dormir', 'baterías', 'cuchillo', 'lata'} tiene utilidad 41.
# El conjunto {'celular', 'mapa', 'baterías', 'lata'} tiene utilidad 24.
# El conjunto {'mapa', 'baterías', 'encendedor', 'lata'} tiene utilidad 25.
# El conjunto {'mapa', 'baterías', 'asador', 'lata'} tiene utilidad 23.
# El conjunto {'mapa', 'baterías', 'computadora', 'lata'} tiene utilidad 21.
# El conjunto {'mapa', 'baterías', 'cuchillo', 'lata'} tiene utilidad 27.
# El conjunto {'celular', 'encendedor', 'baterías', 'lata'} tiene utilidad 26.
# El conjunto {'celular', 'baterías', 'asador', 'lata'} tiene utilidad 24.
# El conjunto {'celular', 'baterías', 'computadora', 'lata'} tiene utilidad 22.
# El conjunto {'celular', 'baterías', 'cuchillo', 'lata'} tiene utilidad 28.
# El conjunto {'encendedor', 'baterías', 'asador', 'lata'} tiene utilidad 25.
# El conjunto {'encendedor', 'baterías', 'computadora', 'lata'} tiene utilidad 23.
# El conjunto {'encendedor', 'baterías', 'cuchillo', 'lata'} tiene utilidad 29.
# El conjunto {'baterías', 'asador', 'computadora', 'lata'} tiene utilidad 21.
# El conjunto {'baterías', 'asador', 'cuchillo', 'lata'} tiene utilidad 27.
# El conjunto {'baterías', 'cuchillo', 'computadora', 'lata'} tiene utilidad 25.
# El conjunto {'bolsa de dormir', 'baterías', 'mapa', 'celular'} tiene utilidad 37.
# El conjunto {'bolsa de dormir', 'baterías', 'mapa', 'encendedor'} tiene utilidad 38.
# El conjunto {'bolsa de dormir', 'baterías', 'asador', 'mapa'} tiene utilidad 36.
# El conjunto {'computadora', 'bolsa de dormir', 'baterías', 'mapa'} tiene utilidad 34.
# El conjunto {'bolsa de dormir', 'baterías', 'cuchillo', 'mapa'} tiene utilidad 40.
# El conjunto {'bolsa de dormir', 'baterías', 'encendedor', 'celular'} tiene utilidad 39.
# El conjunto {'bolsa de dormir', 'baterías', 'asador', 'celular'} tiene utilidad 37.
# El conjunto {'bolsa de dormir', 'baterías', 'computadora', 'celular'} tiene utilidad 35.
# El conjunto {'bolsa de dormir', 'baterías', 'cuchillo', 'celular'} tiene utilidad 41.
# El conjunto {'bolsa de dormir', 'baterías', 'asador', 'encendedor'} tiene utilidad 38.
# El conjunto {'bolsa de dormir', 'baterías', 'computadora', 'encendedor'} tiene utilidad 36.
# El conjunto {'bolsa de dormir', 'baterías', 'cuchillo', 'encendedor'} tiene utilidad 42.
# El conjunto {'bolsa de dormir', 'baterías', 'asador', 'computadora'} tiene utilidad 34.
# El conjunto {'bolsa de dormir', 'baterías', 'asador', 'cuchillo'} tiene utilidad 40.
# El conjunto {'bolsa de dormir', 'baterías', 'cuchillo', 'computadora'} tiene utilidad 38.
# El conjunto {'mapa', 'baterías', 'encendedor', 'celular'} tiene utilidad 25.
# El conjunto {'mapa', 'baterías', 'asador', 'celular'} tiene utilidad 23.
# El conjunto {'mapa', 'baterías', 'computadora', 'celular'} tiene utilidad 21.
# El conjunto {'mapa', 'baterías', 'cuchillo', 'celular'} tiene utilidad 27.
# El conjunto {'mapa', 'baterías', 'asador', 'encendedor'} tiene utilidad 24.
# El conjunto {'mapa', 'baterías', 'computadora', 'encendedor'} tiene utilidad 22.
# El conjunto {'mapa', 'baterías', 'cuchillo', 'encendedor'} tiene utilidad 28.
# El conjunto {'mapa', 'baterías', 'asador', 'computadora'} tiene utilidad 20.
# El conjunto {'mapa', 'baterías', 'asador', 'cuchillo'} tiene utilidad 26.
# El conjunto {'mapa', 'baterías', 'cuchillo', 'computadora'} tiene utilidad 24.
# El conjunto {'encendedor', 'baterías', 'asador', 'celular'} tiene utilidad 25.
# El conjunto {'encendedor', 'baterías', 'computadora', 'celular'} tiene utilidad 23.
# El conjunto {'encendedor', 'baterías', 'cuchillo', 'celular'} tiene utilidad 29.
# El conjunto {'baterías', 'asador', 'computadora', 'celular'} tiene utilidad 21.
# El conjunto {'baterías', 'asador', 'cuchillo', 'celular'} tiene utilidad 27.
# El conjunto {'baterías', 'cuchillo', 'computadora', 'celular'} tiene utilidad 25.
# El conjunto {'baterías', 'asador', 'computadora', 'encendedor'} tiene utilidad 22.
# El conjunto {'baterías', 'asador', 'cuchillo', 'encendedor'} tiene utilidad 28.
# El conjunto {'baterías', 'cuchillo', 'computadora', 'encendedor'} tiene utilidad 26.
# El conjunto {'baterías', 'asador', 'cuchillo', 'computadora'} tiene utilidad 24.
# El conjunto {'celular', 'bolsa de dormir', 'mapa', 'lata'} tiene utilidad 40.
# El conjunto {'bolsa de dormir', 'encendedor', 'mapa', 'lata'} tiene utilidad 41.
# El conjunto {'bolsa de dormir', 'asador', 'mapa', 'lata'} tiene utilidad 39.
# El conjunto {'computadora', 'bolsa de dormir', 'mapa', 'lata'} tiene utilidad 37.
# El conjunto {'bolsa de dormir', 'cuchillo', 'mapa', 'lata'} tiene utilidad 43.
# El conjunto {'celular', 'bolsa de dormir', 'encendedor', 'lata'} tiene utilidad 42.
# El conjunto {'celular', 'bolsa de dormir', 'asador', 'lata'} tiene utilidad 40.
# El conjunto {'celular', 'bolsa de dormir', 'computadora', 'lata'} tiene utilidad 38.
# El conjunto {'celular', 'bolsa de dormir', 'cuchillo', 'lata'} tiene utilidad 44.
# El conjunto {'bolsa de dormir', 'asador', 'encendedor', 'lata'} tiene utilidad 41.
# El conjunto {'bolsa de dormir', 'encendedor', 'computadora', 'lata'} tiene utilidad 39.
# El conjunto {'bolsa de dormir', 'cuchillo', 'encendedor', 'lata'} tiene utilidad 45.
# El conjunto {'bolsa de dormir', 'asador', 'computadora', 'lata'} tiene utilidad 37.
# El conjunto {'bolsa de dormir', 'cuchillo', 'asador', 'lata'} tiene utilidad 43.
# El conjunto {'bolsa de dormir', 'cuchillo', 'computadora', 'lata'} tiene utilidad 41.
# El conjunto {'celular', 'mapa', 'encendedor', 'lata'} tiene utilidad 28.
# El conjunto {'celular', 'mapa', 'asador', 'lata'} tiene utilidad 26.
# El conjunto {'celular', 'mapa', 'computadora', 'lata'} tiene utilidad 24.
# El conjunto {'celular', 'mapa', 'cuchillo', 'lata'} tiene utilidad 30.
# El conjunto {'mapa', 'asador', 'encendedor', 'lata'} tiene utilidad 27.
# El conjunto {'mapa', 'encendedor', 'computadora', 'lata'} tiene utilidad 25.
# El conjunto {'mapa', 'cuchillo', 'encendedor', 'lata'} tiene utilidad 31.
# El conjunto {'mapa', 'asador', 'computadora', 'lata'} tiene utilidad 23.
# El conjunto {'mapa', 'cuchillo', 'asador', 'lata'} tiene utilidad 29.
# El conjunto {'mapa', 'cuchillo', 'computadora', 'lata'} tiene utilidad 27.
# El conjunto {'celular', 'encendedor', 'asador', 'lata'} tiene utilidad 28.
# El conjunto {'celular', 'encendedor', 'computadora', 'lata'} tiene utilidad 26.
# El conjunto {'celular', 'encendedor', 'cuchillo', 'lata'} tiene utilidad 32.
# El conjunto {'celular', 'asador', 'computadora', 'lata'} tiene utilidad 24.
# El conjunto {'celular', 'cuchillo', 'asador', 'lata'} tiene utilidad 30.
# El conjunto {'celular', 'cuchillo', 'computadora', 'lata'} tiene utilidad 28.
# El conjunto {'encendedor', 'asador', 'computadora', 'lata'} tiene utilidad 25.
# El conjunto {'encendedor', 'cuchillo', 'asador', 'lata'} tiene utilidad 31.
# El conjunto {'encendedor', 'cuchillo', 'computadora', 'lata'} tiene utilidad 29.
# El conjunto {'cuchillo', 'asador', 'computadora', 'lata'} tiene utilidad 27.
# El conjunto {'bolsa de dormir', 'encendedor', 'mapa', 'celular'} tiene utilidad 41.
# El conjunto {'bolsa de dormir', 'asador', 'mapa', 'celular'} tiene utilidad 39.
# El conjunto {'computadora', 'bolsa de dormir', 'mapa', 'celular'} tiene utilidad 37.
# El conjunto {'bolsa de dormir', 'cuchillo', 'mapa', 'celular'} tiene utilidad 43.
# El conjunto {'bolsa de dormir', 'asador', 'mapa', 'encendedor'} tiene utilidad 40.
# El conjunto {'computadora', 'bolsa de dormir', 'mapa', 'encendedor'} tiene utilidad 38.
# El conjunto {'bolsa de dormir', 'cuchillo', 'mapa', 'encendedor'} tiene utilidad 44.
# El conjunto {'computadora', 'bolsa de dormir', 'asador', 'mapa'} tiene utilidad 36.
# El conjunto {'bolsa de dormir', 'cuchillo', 'asador', 'mapa'} tiene utilidad 42.
# El conjunto {'computadora', 'bolsa de dormir', 'cuchillo', 'mapa'} tiene utilidad 40.
# El conjunto {'bolsa de dormir', 'asador', 'encendedor', 'celular'} tiene utilidad 41.
# El conjunto {'bolsa de dormir', 'encendedor', 'computadora', 'celular'} tiene utilidad 39.
# El conjunto {'bolsa de dormir', 'cuchillo', 'encendedor', 'celular'} tiene utilidad 45.
# El conjunto {'bolsa de dormir', 'asador', 'computadora', 'celular'} tiene utilidad 37.
# El conjunto {'bolsa de dormir', 'cuchillo', 'asador', 'celular'} tiene utilidad 43.
# El conjunto {'bolsa de dormir', 'cuchillo', 'computadora', 'celular'} tiene utilidad 41.
# El conjunto {'bolsa de dormir', 'asador', 'computadora', 'encendedor'} tiene utilidad 38.
# El conjunto {'bolsa de dormir', 'cuchillo', 'asador', 'encendedor'} tiene utilidad 44.
# El conjunto {'bolsa de dormir', 'cuchillo', 'computadora', 'encendedor'} tiene utilidad 42.
# El conjunto {'bolsa de dormir', 'cuchillo', 'asador', 'computadora'} tiene utilidad 40.
# El conjunto {'mapa', 'asador', 'encendedor', 'celular'} tiene utilidad 27.
# El conjunto {'mapa', 'encendedor', 'computadora', 'celular'} tiene utilidad 25.
# El conjunto {'mapa', 'cuchillo', 'encendedor', 'celular'} tiene utilidad 31.
# El conjunto {'mapa', 'asador', 'computadora', 'celular'} tiene utilidad 23.
# El conjunto {'mapa', 'cuchillo', 'asador', 'celular'} tiene utilidad 29.
# El conjunto {'mapa', 'cuchillo', 'computadora', 'celular'} tiene utilidad 27.
# El conjunto {'mapa', 'asador', 'computadora', 'encendedor'} tiene utilidad 24.
# El conjunto {'mapa', 'cuchillo', 'asador', 'encendedor'} tiene utilidad 30.
# El conjunto {'mapa', 'cuchillo', 'computadora', 'encendedor'} tiene utilidad 28.
# El conjunto {'mapa', 'cuchillo', 'asador', 'computadora'} tiene utilidad 26.
# El conjunto {'encendedor', 'asador', 'computadora', 'celular'} tiene utilidad 25.
# El conjunto {'encendedor', 'cuchillo', 'asador', 'celular'} tiene utilidad 31.
# El conjunto {'encendedor', 'cuchillo', 'computadora', 'celular'} tiene utilidad 29.
# El conjunto {'cuchillo', 'asador', 'computadora', 'celular'} tiene utilidad 27.
# El conjunto {'cuchillo', 'asador', 'computadora', 'encendedor'} tiene utilidad 28.
# El conjunto {'bolsa de dormir', 'libro', 'baterías', 'linterna', 'lata'} tiene utilidad 43.
# El conjunto {'mapa', 'libro', 'baterías', 'linterna', 'lata'} tiene utilidad 29.
# El conjunto {'lata', 'libro', 'baterías', 'linterna', 'celular'} tiene utilidad 30.
# El conjunto {'lata', 'libro', 'baterías', 'linterna', 'encendedor'} tiene utilidad 31.
# El conjunto {'libro', 'baterías', 'asador', 'linterna', 'lata'} tiene utilidad 29.
# El conjunto {'libro', 'computadora', 'baterías', 'linterna', 'lata'} tiene utilidad 27.
# El conjunto {'cuchillo', 'libro', 'baterías', 'linterna', 'lata'} tiene utilidad 33.
# El conjunto {'bolsa de dormir', 'mapa', 'libro', 'baterías', 'linterna'} tiene utilidad 42.
# El conjunto {'bolsa de dormir', 'libro', 'baterías', 'linterna', 'celular'} tiene utilidad 43.
# El conjunto {'bolsa de dormir', 'libro', 'baterías', 'linterna', 'encendedor'} tiene utilidad 44.
# El conjunto {'bolsa de dormir', 'libro', 'baterías', 'asador', 'linterna'} tiene utilidad 42.
# El conjunto {'bolsa de dormir', 'libro', 'computadora', 'baterías', 'linterna'} tiene utilidad 40.
# El conjunto {'cuchillo', 'bolsa de dormir', 'libro', 'baterías', 'linterna'} tiene utilidad 46.
# El conjunto {'mapa', 'libro', 'baterías', 'linterna', 'celular'} tiene utilidad 29.
# El conjunto {'mapa', 'libro', 'baterías', 'linterna', 'encendedor'} tiene utilidad 30.
# El conjunto {'mapa', 'libro', 'baterías', 'asador', 'linterna'} tiene utilidad 28.
# El conjunto {'mapa', 'libro', 'computadora', 'baterías', 'linterna'} tiene utilidad 26.
# El conjunto {'cuchillo', 'mapa', 'libro', 'baterías', 'linterna'} tiene utilidad 32.
# El conjunto {'linterna', 'libro', 'baterías', 'encendedor', 'celular'} tiene utilidad 31.
# El conjunto {'libro', 'baterías', 'asador', 'linterna', 'celular'} tiene utilidad 29.
# El conjunto {'libro', 'computadora', 'baterías', 'linterna', 'celular'} tiene utilidad 27.
# El conjunto {'cuchillo', 'libro', 'baterías', 'linterna', 'celular'} tiene utilidad 33.
# El conjunto {'libro', 'baterías', 'asador', 'linterna', 'encendedor'} tiene utilidad 30.
# El conjunto {'libro', 'computadora', 'baterías', 'linterna', 'encendedor'} tiene utilidad 28.
# El conjunto {'cuchillo', 'libro', 'baterías', 'linterna', 'encendedor'} tiene utilidad 34.
# El conjunto {'libro', 'computadora', 'baterías', 'asador', 'linterna'} tiene utilidad 26.
# El conjunto {'cuchillo', 'libro', 'baterías', 'asador', 'linterna'} tiene utilidad 32.
# El conjunto {'cuchillo', 'libro', 'computadora', 'baterías', 'linterna'} tiene utilidad 30.
# El conjunto {'bolsa de dormir', 'mapa', 'libro', 'linterna', 'lata'} tiene utilidad 45.
# El conjunto {'bolsa de dormir', 'lata', 'libro', 'linterna', 'celular'} tiene utilidad 46.
# El conjunto {'bolsa de dormir', 'linterna', 'libro', 'encendedor', 'lata'} tiene utilidad 47.
# El conjunto {'bolsa de dormir', 'libro', 'asador', 'linterna', 'lata'} tiene utilidad 45.
# El conjunto {'bolsa de dormir', 'libro', 'computadora', 'linterna', 'lata'} tiene utilidad 43.
# El conjunto {'cuchillo', 'bolsa de dormir', 'libro', 'linterna', 'lata'} tiene utilidad 49.
# El conjunto {'mapa', 'lata', 'libro', 'linterna', 'celular'} tiene utilidad 32.
# El conjunto {'mapa', 'linterna', 'libro', 'encendedor', 'lata'} tiene utilidad 33.
# El conjunto {'mapa', 'libro', 'asador', 'linterna', 'lata'} tiene utilidad 31.
# El conjunto {'mapa', 'libro', 'computadora', 'linterna', 'lata'} tiene utilidad 29.
# El conjunto {'cuchillo', 'mapa', 'libro', 'linterna', 'lata'} tiene utilidad 35.
# El conjunto {'lata', 'libro', 'linterna', 'encendedor', 'celular'} tiene utilidad 34.
# El conjunto {'lata', 'libro', 'asador', 'linterna', 'celular'} tiene utilidad 32.
# El conjunto {'lata', 'libro', 'computadora', 'linterna', 'celular'} tiene utilidad 30.
# El conjunto {'cuchillo', 'lata', 'libro', 'linterna', 'celular'} tiene utilidad 36.
# El conjunto {'lata', 'libro', 'asador', 'linterna', 'encendedor'} tiene utilidad 33.
# El conjunto {'lata', 'libro', 'computadora', 'linterna', 'encendedor'} tiene utilidad 31.
# El conjunto {'cuchillo', 'lata', 'libro', 'linterna', 'encendedor'} tiene utilidad 37.
# El conjunto {'libro', 'computadora', 'asador', 'linterna', 'lata'} tiene utilidad 29.
# El conjunto {'cuchillo', 'libro', 'asador', 'linterna', 'lata'} tiene utilidad 35.
# El conjunto {'cuchillo', 'libro', 'computadora', 'linterna', 'lata'} tiene utilidad 33.
# El conjunto {'bolsa de dormir', 'mapa', 'libro', 'linterna', 'celular'} tiene utilidad 45.
# El conjunto {'bolsa de dormir', 'mapa', 'libro', 'linterna', 'encendedor'} tiene utilidad 46.
# El conjunto {'bolsa de dormir', 'mapa', 'libro', 'asador', 'linterna'} tiene utilidad 44.
# El conjunto {'bolsa de dormir', 'mapa', 'libro', 'computadora', 'linterna'} tiene utilidad 42.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'linterna'} tiene utilidad 48.
# El conjunto {'bolsa de dormir', 'linterna', 'libro', 'encendedor', 'celular'} tiene utilidad 47.
# El conjunto {'bolsa de dormir', 'libro', 'asador', 'linterna', 'celular'} tiene utilidad 45.
# El conjunto {'bolsa de dormir', 'libro', 'computadora', 'linterna', 'celular'} tiene utilidad 43.
# El conjunto {'cuchillo', 'bolsa de dormir', 'libro', 'linterna', 'celular'} tiene utilidad 49.
# El conjunto {'bolsa de dormir', 'libro', 'asador', 'linterna', 'encendedor'} tiene utilidad 46.
# El conjunto {'bolsa de dormir', 'libro', 'computadora', 'linterna', 'encendedor'} tiene utilidad 44.
# El conjunto {'cuchillo', 'bolsa de dormir', 'libro', 'linterna', 'encendedor'} tiene utilidad 50.
# El conjunto {'bolsa de dormir', 'libro', 'computadora', 'asador', 'linterna'} tiene utilidad 42.
# El conjunto {'cuchillo', 'bolsa de dormir', 'libro', 'asador', 'linterna'} tiene utilidad 48.
# El conjunto {'cuchillo', 'bolsa de dormir', 'libro', 'computadora', 'linterna'} tiene utilidad 46.
# El conjunto {'mapa', 'linterna', 'libro', 'encendedor', 'celular'} tiene utilidad 33.
# El conjunto {'mapa', 'libro', 'asador', 'linterna', 'celular'} tiene utilidad 31.
# El conjunto {'mapa', 'libro', 'computadora', 'linterna', 'celular'} tiene utilidad 29.
# El conjunto {'cuchillo', 'mapa', 'libro', 'linterna', 'celular'} tiene utilidad 35.
# El conjunto {'mapa', 'libro', 'asador', 'linterna', 'encendedor'} tiene utilidad 32.
# El conjunto {'mapa', 'libro', 'computadora', 'linterna', 'encendedor'} tiene utilidad 30.
# El conjunto {'cuchillo', 'mapa', 'libro', 'linterna', 'encendedor'} tiene utilidad 36.
# El conjunto {'mapa', 'libro', 'computadora', 'asador', 'linterna'} tiene utilidad 28.
# El conjunto {'cuchillo', 'mapa', 'libro', 'asador', 'linterna'} tiene utilidad 34.
# El conjunto {'cuchillo', 'mapa', 'libro', 'computadora', 'linterna'} tiene utilidad 32.
# El conjunto {'linterna', 'libro', 'asador', 'encendedor', 'celular'} tiene utilidad 33.
# El conjunto {'linterna', 'libro', 'computadora', 'encendedor', 'celular'} tiene utilidad 31.
# El conjunto {'cuchillo', 'linterna', 'libro', 'encendedor', 'celular'} tiene utilidad 37.
# El conjunto {'libro', 'computadora', 'asador', 'linterna', 'celular'} tiene utilidad 29.
# El conjunto {'cuchillo', 'libro', 'asador', 'linterna', 'celular'} tiene utilidad 35.
# El conjunto {'cuchillo', 'libro', 'computadora', 'linterna', 'celular'} tiene utilidad 33.
# ...
# El conjunto {'cuchillo', 'bolsa de dormir', 'lata', 'mapa', 'computadora', 'linterna', 'encendedor', 'celular'} tiene utilidad 72.
# El conjunto {'cuchillo', 'bolsa de dormir', 'lata', 'mapa', 'computadora', 'asador', 'linterna', 'celular'} tiene utilidad 70.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'linterna', 'computadora', 'asador', 'encendedor', 'lata'} tiene utilidad 71.
# El conjunto {'cuchillo', 'bolsa de dormir', 'lata', 'linterna', 'computadora', 'asador', 'encendedor', 'celular'} tiene utilidad 72.
# El conjunto {'cuchillo', 'mapa', 'lata', 'linterna', 'computadora', 'asador', 'encendedor', 'celular'} tiene utilidad 58.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'linterna', 'computadora', 'asador', 'encendedor', 'celular'} tiene utilidad 71.
# El conjunto {'bolsa de dormir', 'mapa', 'libro', 'baterías', 'asador', 'encendedor', 'celular', 'lata'} tiene utilidad 60.
# El conjunto {'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'encendedor', 'celular', 'lata'} tiene utilidad 58.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'baterías', 'encendedor', 'celular', 'lata'} tiene utilidad 64.
# El conjunto {'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'asador', 'celular', 'lata'} tiene utilidad 56.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'baterías', 'asador', 'celular', 'lata'} tiene utilidad 62.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'celular', 'lata'} tiene utilidad 60.
# El conjunto {'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'asador', 'encendedor', 'lata'} tiene utilidad 57.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'baterías', 'asador', 'encendedor', 'lata'} tiene utilidad 63.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'encendedor', 'lata'} tiene utilidad 61.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'asador', 'lata'} tiene utilidad 59.
# El conjunto {'bolsa de dormir', 'lata', 'libro', 'computadora', 'baterías', 'asador', 'encendedor', 'celular'} tiene utilidad 58.
# El conjunto {'cuchillo', 'bolsa de dormir', 'lata', 'libro', 'baterías', 'asador', 'encendedor', 'celular'} tiene utilidad 64.
# El conjunto {'cuchillo', 'bolsa de dormir', 'lata', 'libro', 'computadora', 'baterías', 'encendedor', 'celular'} tiene utilidad 62.
# El conjunto {'cuchillo', 'bolsa de dormir', 'lata', 'libro', 'computadora', 'baterías', 'asador', 'celular'} tiene utilidad 60.
# El conjunto {'cuchillo', 'bolsa de dormir', 'lata', 'libro', 'computadora', 'baterías', 'asador', 'encendedor'} tiene utilidad 61.
# El conjunto {'mapa', 'lata', 'libro', 'computadora', 'baterías', 'asador', 'encendedor', 'celular'} tiene utilidad 44.
# El conjunto {'cuchillo', 'mapa', 'lata', 'libro', 'baterías', 'asador', 'encendedor', 'celular'} tiene utilidad 50.
# El conjunto {'cuchillo', 'mapa', 'lata', 'libro', 'computadora', 'baterías', 'encendedor', 'celular'} tiene utilidad 48.
# El conjunto {'cuchillo', 'mapa', 'lata', 'libro', 'computadora', 'baterías', 'asador', 'celular'} tiene utilidad 46.
# El conjunto {'cuchillo', 'mapa', 'lata', 'libro', 'computadora', 'baterías', 'asador', 'encendedor'} tiene utilidad 47.
# El conjunto {'cuchillo', 'lata', 'libro', 'computadora', 'baterías', 'asador', 'encendedor', 'celular'} tiene utilidad 48.
# El conjunto {'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'asador', 'encendedor', 'celular'} tiene utilidad 57.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'baterías', 'asador', 'encendedor', 'celular'} tiene utilidad 63.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'encendedor', 'celular'} tiene utilidad 61.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'asador', 'celular'} tiene utilidad 59.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'asador', 'encendedor'} tiene utilidad 60.
# El conjunto {'cuchillo', 'bolsa de dormir', 'libro', 'computadora', 'baterías', 'asador', 'celular', 'encendedor'} tiene utilidad 61.
# El conjunto {'cuchillo', 'mapa', 'libro', 'computadora', 'baterías', 'asador', 'celular', 'encendedor'} tiene utilidad 47.
# El conjunto {'bolsa de dormir', 'mapa', 'libro', 'lata', 'computadora', 'asador', 'encendedor', 'celular'} tiene utilidad 60.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'lata', 'asador', 'encendedor', 'celular'} tiene utilidad 66.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'lata', 'computadora', 'encendedor', 'celular'} tiene utilidad 64.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'lata', 'computadora', 'asador', 'celular'} tiene utilidad 62.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'lata', 'computadora', 'asador', 'encendedor'} tiene utilidad 63.
# El conjunto {'cuchillo', 'bolsa de dormir', 'lata', 'libro', 'computadora', 'asador', 'encendedor', 'celular'} tiene utilidad 64.
# El conjunto {'cuchillo', 'mapa', 'lata', 'libro', 'computadora', 'asador', 'encendedor', 'celular'} tiene utilidad 50.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'computadora', 'asador', 'celular', 'encendedor'} tiene utilidad 63.
# El conjunto {'bolsa de dormir', 'mapa', 'lata', 'computadora', 'baterías', 'asador', 'encendedor', 'celular'} tiene utilidad 62.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'lata', 'baterías', 'asador', 'encendedor', 'celular'} tiene utilidad 68.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'lata', 'computadora', 'baterías', 'encendedor', 'celular'} tiene utilidad 66.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'lata', 'computadora', 'baterías', 'asador', 'celular'} tiene utilidad 64.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'lata', 'computadora', 'baterías', 'asador', 'encendedor'} tiene utilidad 65.
# El conjunto {'cuchillo', 'bolsa de dormir', 'lata', 'computadora', 'baterías', 'asador', 'encendedor', 'celular'} tiene utilidad 66.
# El conjunto {'cuchillo', 'mapa', 'lata', 'computadora', 'baterías', 'asador', 'encendedor', 'celular'} tiene utilidad 52.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'computadora', 'baterías', 'asador', 'celular', 'encendedor'} tiene utilidad 65.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'lata', 'computadora', 'asador', 'encendedor', 'celular'} tiene utilidad 68.
# El conjunto {'bolsa de dormir', 'mapa', 'libro', 'baterías', 'asador', 'linterna', 'celular', 'encendedor', 'lata'} tiene utilidad 70.
# El conjunto {'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'linterna', 'celular', 'encendedor', 'lata'} tiene utilidad 68.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'baterías', 'linterna', 'celular', 'encendedor', 'lata'} tiene utilidad 74.
# El conjunto {'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'asador', 'linterna', 'celular', 'lata'} tiene utilidad 66.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'baterías', 'asador', 'linterna', 'celular', 'lata'} tiene utilidad 72.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'linterna', 'celular', 'lata'} tiene utilidad 70.
# El conjunto {'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'asador', 'linterna', 'encendedor', 'lata'} tiene utilidad 67.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'baterías', 'asador', 'linterna', 'encendedor', 'lata'} tiene utilidad 73.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'linterna', 'encendedor', 'lata'} tiene utilidad 71.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'asador', 'linterna', 'lata'} tiene utilidad 69.
# El conjunto {'bolsa de dormir', 'libro', 'computadora', 'baterías', 'asador', 'linterna', 'celular', 'encendedor', 'lata'} tiene utilidad 68.
# El conjunto {'cuchillo', 'bolsa de dormir', 'libro', 'baterías', 'asador', 'linterna', 'celular', 'encendedor', 'lata'} tiene utilidad 74.
# El conjunto {'cuchillo', 'bolsa de dormir', 'libro', 'computadora', 'baterías', 'linterna', 'celular', 'encendedor', 'lata'} tiene utilidad 72.
# El conjunto {'cuchillo', 'bolsa de dormir', 'libro', 'computadora', 'baterías', 'asador', 'linterna', 'celular', 'lata'} tiene utilidad 70.
# El conjunto {'cuchillo', 'bolsa de dormir', 'libro', 'computadora', 'baterías', 'asador', 'linterna', 'encendedor', 'lata'} tiene utilidad 71.
# El conjunto {'mapa', 'libro', 'computadora', 'baterías', 'asador', 'linterna', 'celular', 'encendedor', 'lata'} tiene utilidad 54.
# El conjunto {'cuchillo', 'mapa', 'libro', 'baterías', 'asador', 'linterna', 'celular', 'encendedor', 'lata'} tiene utilidad 60.
# El conjunto {'cuchillo', 'mapa', 'libro', 'computadora', 'baterías', 'linterna', 'celular', 'encendedor', 'lata'} tiene utilidad 58.
# El conjunto {'cuchillo', 'mapa', 'libro', 'computadora', 'baterías', 'asador', 'linterna', 'celular', 'lata'} tiene utilidad 56.
# El conjunto {'cuchillo', 'mapa', 'libro', 'computadora', 'baterías', 'asador', 'linterna', 'encendedor', 'lata'} tiene utilidad 57.
# El conjunto {'cuchillo', 'lata', 'libro', 'computadora', 'baterías', 'asador', 'linterna', 'encendedor', 'celular'} tiene utilidad 58.
# El conjunto {'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'asador', 'linterna', 'encendedor', 'celular'} tiene utilidad 67.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'baterías', 'asador', 'linterna', 'encendedor', 'celular'} tiene utilidad 73.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'linterna', 'encendedor', 'celular'} tiene utilidad 71.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'asador', 'linterna', 'celular'} tiene utilidad 69.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'asador', 'linterna', 'encendedor'} tiene utilidad 70.
# El conjunto {'cuchillo', 'bolsa de dormir', 'libro', 'computadora', 'baterías', 'asador', 'linterna', 'encendedor', 'celular'} tiene utilidad 71.
# El conjunto {'cuchillo', 'mapa', 'libro', 'computadora', 'baterías', 'asador', 'linterna', 'encendedor', 'celular'} tiene utilidad 57.
# El conjunto {'bolsa de dormir', 'mapa', 'libro', 'computadora', 'asador', 'linterna', 'celular', 'encendedor', 'lata'} tiene utilidad 70.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'asador', 'linterna', 'celular', 'encendedor', 'lata'} tiene utilidad 76.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'computadora', 'linterna', 'celular', 'encendedor', 'lata'} tiene utilidad 74.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'computadora', 'asador', 'linterna', 'celular', 'lata'} tiene utilidad 72.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'computadora', 'asador', 'linterna', 'encendedor', 'lata'} tiene utilidad 73.
# El conjunto {'cuchillo', 'bolsa de dormir', 'lata', 'libro', 'computadora', 'asador', 'linterna', 'encendedor', 'celular'} tiene utilidad 74.
# El conjunto {'cuchillo', 'mapa', 'lata', 'libro', 'computadora', 'asador', 'linterna', 'encendedor', 'celular'} tiene utilidad 60.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'computadora', 'asador', 'linterna', 'encendedor', 'celular'} tiene utilidad 73.
# El conjunto {'bolsa de dormir', 'mapa', 'computadora', 'baterías', 'asador', 'linterna', 'celular', 'encendedor', 'lata'} tiene utilidad 72.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'baterías', 'asador', 'linterna', 'celular', 'encendedor', 'lata'} tiene utilidad 78.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'computadora', 'baterías', 'linterna', 'celular', 'encendedor', 'lata'} tiene utilidad 76.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'computadora', 'baterías', 'asador', 'linterna', 'celular', 'lata'} tiene utilidad 74.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'computadora', 'baterías', 'asador', 'linterna', 'encendedor', 'lata'} tiene utilidad 75.
# El conjunto {'cuchillo', 'bolsa de dormir', 'lata', 'computadora', 'baterías', 'asador', 'linterna', 'encendedor', 'celular'} tiene utilidad 76.
# El conjunto {'cuchillo', 'mapa', 'lata', 'computadora', 'baterías', 'asador', 'linterna', 'encendedor', 'celular'} tiene utilidad 62.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'computadora', 'baterías', 'asador', 'linterna', 'encendedor', 'celular'} tiene utilidad 75.
# El conjunto {'cuchillo', 'bolsa de dormir', 'lata', 'mapa', 'computadora', 'asador', 'linterna', 'encendedor', 'celular'} tiene utilidad 78.
# El conjunto {'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'asador', 'encendedor', 'celular', 'lata'} tiene utilidad 64.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'baterías', 'asador', 'encendedor', 'celular', 'lata'} tiene utilidad 70.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'encendedor', 'celular', 'lata'} tiene utilidad 68.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'asador', 'celular', 'lata'} tiene utilidad 66.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'asador', 'encendedor', 'lata'} tiene utilidad 67.
# El conjunto {'cuchillo', 'bolsa de dormir', 'lata', 'libro', 'computadora', 'baterías', 'asador', 'encendedor', 'celular'} tiene utilidad 68.
# El conjunto {'cuchillo', 'mapa', 'lata', 'libro', 'computadora', 'baterías', 'asador', 'encendedor', 'celular'} tiene utilidad 54.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'asador', 'encendedor', 'celular'} tiene utilidad 67.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'lata', 'computadora', 'asador', 'encendedor', 'celular'} tiene utilidad 70.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'lata', 'computadora', 'baterías', 'asador', 'encendedor', 'celular'} tiene utilidad 72.
# El conjunto {'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'asador', 'linterna', 'celular', 'encendedor', 'lata'} tiene utilidad 74.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'baterías', 'asador', 'linterna', 'celular', 'encendedor', 'lata'} tiene utilidad 80.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'linterna', 'celular', 'encendedor', 'lata'} tiene utilidad 78.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'asador', 'linterna', 'celular', 'lata'} tiene utilidad 76.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'asador', 'linterna', 'encendedor', 'lata'} tiene utilidad 77.
# El conjunto {'cuchillo', 'bolsa de dormir', 'libro', 'computadora', 'baterías', 'asador', 'linterna', 'celular', 'encendedor', 'lata'} tiene utilidad 78.
# El conjunto {'cuchillo', 'mapa', 'libro', 'computadora', 'baterías', 'asador', 'linterna', 'celular', 'encendedor', 'lata'} tiene utilidad 64.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'asador', 'linterna', 'encendedor', 'celular'} tiene utilidad 77.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'computadora', 'asador', 'linterna', 'celular', 'encendedor', 'lata'} tiene utilidad 80.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'computadora', 'baterías', 'asador', 'linterna', 'celular', 'encendedor', 'lata'} tiene utilidad 82.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'asador', 'encendedor', 'celular', 'lata'} tiene utilidad 74.
# El conjunto {'cuchillo', 'bolsa de dormir', 'mapa', 'libro', 'computadora', 'baterías', 'asador', 'linterna', 'celular', 'encendedor', 'lata'} tiene utilidad 84.

# %% [markdown]
# Definimos una función que dado un subconjunto de objetos y un límite, determine si el conjunto es factible (si su peso total es cuando mucho el límite).
#
# factible -> feasible

# %%
def es_factible(conjunto, límite, parámetro=peso):
    return suma(conjunto, parámetro) <= límite

es_factible({"bolsa de dormir", "asador"}, 15)
# Out:
# False

# %% [markdown]
# Con esto, definimos una función para resolver el problema de la mochila.

# %%
def problema_mochila(pesos, utilidades, límite):
    subconjuntos = todos_subconjuntos(pesos)
    conjunto_óptimo = set()
    for conjunto in subconjuntos:
        if es_factible(conjunto, límite, parámetro=pesos):
            if suma(conjunto, utilidad) > suma(conjunto_óptimo, utilidad):
                conjunto_óptimo = conjunto.copy()
                # print(f"El conjunto óptimo hasta ahora es {conjunto_óptimo}")
                # print(f"Con peso {suma(conjunto_óptimo, peso)} y utilidad {suma(conjunto_óptimo, utilidad)}")
    return conjunto_óptimo

resultado = problema_mochila(peso, utilidad, 15)
resultado
# Out:
# {'baterías',
#  'bolsa de dormir',
#  'computadora',
#  'encendedor',
#  'linterna',
#  'mapa'}

# %%
suma(resultado, utilidad), suma(resultado, peso)
# Out:
# (55, 15)

# %% [markdown]
# ## Otra manera de resolver el problema

# %% [markdown]
# Usaremos que la función `max` obtiene el máximo de los elementos de una lista

# %%
max([3, 4, 21, 20, 5, -3, 9, 12])
# Out:
# 21

# %% [markdown]
# También funciona en tuplas, puesto que las tuplas se ordenan por *orden del diccionario*.

# %%
max([(2, 10), (4, 3), (-2, 3), (4, 8)])
# Out:
# (4, 8)

# %%
todos = todos_subconjuntos(peso)
len(todos) == 2**len(peso), len(todos)
# Out:
# (True, 2048)

# %% [markdown]
# Vamos ahora a filtrar los subconjuntos factibles.

# %%
factibles = [sub for sub in todos if es_factible(sub, 15)]
len(factibles)

# %%
utilidades = [(suma(sub, utilidad), sub, suma(sub, peso)) for sub in factibles]
max(utilidades)

# %%
[]

# %% [markdown]
# ## Tarea

# %% [markdown]
# TAREA: Generar datos para el problema de la mochila.
#
# Sirve la biblioteca `random`

# %%
from random import randint

randint(0,20)

# %%
peso = {i: randint(1, 30) for i in range(10)}
utilidad = {i: randint(1, 30) for i in range(10)}
peso, utilidad

# %% [markdown]
# 27, 10
# 8, 10
# 11, 2
# 22, 6

# %%
resultado = problema_mochila(peso, utilidad, 16)
resultado

# %%
suma(resultado, utilidad), suma(resultado, peso)

# %% [markdown]
# Un aspecto que podemos mejorar, es que los datos que definen una instancia del problema de la mochila deben considerarse como un todo. Un intento de resolverlo, podría ser que incluyéramos en un diccionario, juntos el peso y la utilidad.

# %%
datos_mochila = {i: [randint(1, 20), randint(1,20)] for i in range(10)}
datos_mochila

# %% [markdown]
# Pero en este caso, podríamos olvidar que el primer elemento de la lista es el peso y el segundo la utilidad. Más adelante, cuando veamos el concepto *clases*, éste nos servirá para crear nuevos objetos con las características que deseemos, como por ejemplo, juntar la lista de objetos, sus utilidades, sus pesos, y el límite de la mochila en un solo objeto.

# %%
problema = (peso, utilidad, 40)
problema

# %% [markdown]
# *unpacking*  <- Desempacar una tupla, para poder usar sus tres componentes como argumentos de una función que espera los tres argumentos.

# %%
problema_mochila(*problema)
